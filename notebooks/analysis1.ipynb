# %% [markdown]
# # Jasmine Han

# %% [markdown]
# ## Research question/interests
#
# My research interests involve investigating the ways that human-derived stressors and anthropogenic climate-change effect natural landscapes. By interpreting data obtained from effected regions, what are personalized ways to mitigate the effects?

# %%
import pandas as pd
pd.read_csv("../data/raw/EMLSdata_10Aug.csv")
# Out:
#      Lake_ID        Date                LakeName    LabName      Country  \
# 0     AT_MON  2015-08-03                 Mondsee     WEISSE      Austria
# 1     CH_BRE  2015-08-12                  Brenet      FOREL  Switzerland
# 2    CH_BRET  2015-08-25                    Bret      FOREL  Switzerland
# 3     CH_DIV  2015-08-14                 Divonne      FOREL  Switzerland
# 4     CH_GE3  2015-08-10              Geneva_GE3      FOREL  Switzerland
# ..       ...         ...                     ...        ...          ...
# 364   UK_ERN  2015-08-17                    Erne       AFBI           UK
# 365  UK_GRAS  2015-08-17                Grasmere  Lancaster           UK
# 366   UK_NEA  2015-08-24                   Neagh       AFBI           UK
# 367    UK_WN  2015-08-18  Windermere North Basin  Lancaster           UK
# 368    UK_WS  2015-08-18  Windermere South Basin  Lancaster           UK
#
#       Latitude  Longitude  Altitude_m  MaximumDepth_m  MeanDepth_m  ...  \
# ...
